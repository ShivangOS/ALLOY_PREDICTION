# %%
import pandas as pd

df = pd.read_csv("./HEA Phase DataSet v1d.csv")

# %% [markdown]
# ## Synthesis_Route
#
# AC
# - Arc Cast / Arc Melted
# - Verified from DOI:
#   10.xxxxx
# - Usually melted under Ar atmosphere
# - Often drop cast into Cu mold
#
# PM
# - Powder Metallurgy
# - Verified from DOI:
#   10.xxxxx
# - Includes powder processing routes such as SEBM
#
# Unknown
# - 1 missing entry

# %%
df["Sythesis_Route"].unique()
# Out:
# <StringArray>
# ['AC', 'PM', nan]
# Length: 3, dtype: str

# %%
df["Sythesis_Route"].value_counts(dropna=False)
# Out:
# Sythesis_Route
# AC     1284
# PM       76
# NaN       1
# Name: count, dtype: int64

# %%
df["Hot-Cold_Working"].unique()
# Out:
# <StringArray>
# [nan, 'CW', 'HIP', 'HW']
# Length: 4, dtype: str

# %%
df["Homogenization_Temp"].unique()
# Out:
# array([  nan, 1400., 1200., 1100., 1050., 1000.,  850.,  975., 1150.,
#        1500., 1600., 1700.,  800.,  900., 1220., 1250.,  960., 1450.,
#         500., 1180.,  600.,  700., 1140.])

# %%
df["Homogenization_Time"].unique()
# Out:
# array([      nan, 1.200e+02, 1.440e+03, 6.000e+02, 3.000e+02, 3.600e+02,
#        1.300e+03, 6.000e+01, 1.800e+02, 1.400e+03, 2.880e+03, 8.000e+00,
#        1.000e+01, 3.000e+01, 5.000e+00, 1.200e+03, 3.600e+03, 3.000e+03,
#        2.400e+02, 2.000e+00, 1.441e+03, 2.800e+02, 1.500e+01])

# %%
df["Annealing_Temp"].unique()
# Out:
# <StringArray>
# [   nan, '1400', '1300', '1200', '1000',  '900', '1050',  '650',  '360',
#   '800', '1150',  '500',  '600',  '645',  '700',  '550',  '925',  '950',
#   '450',  '850',  '400',  '830', '1040', '1100',  '750',  '675', '600?',
#   '300',   '25',  '620',  '110', '1800',  '625', '900?',  '780',    '0']
# Length: 36, dtype: str

# %%
df["Annealing_Time_(min)"].unique()
# Out:
# array([      nan, 1.440e+03, 1.200e+03, 6.000e+01, 3.000e+01, 2.400e+02,
#        1.400e+03, 1.500e+03, 3.000e+02, 3.000e+03, 1.200e+02, 0.000e+00,
#        3.600e+02, 6.000e+02, 6.000e+03, 4.800e+02, 1.000e+01, 7.200e+01,
#        7.200e+02, 1.500e+01, 5.000e+00, 3.000e+00, 2.000e+01, 2.000e+00,
#        1.140e+03, 1.080e+03, 1.008e+04, 9.600e+02, 3.840e+03, 1.536e+04,
#        4.320e+03, 9.000e+02, 7.200e+03, 4.200e+03, 9.000e+03, 1.464e+03,
#        1.872e+04, 6.048e+04, 4.500e+01, 1.800e+02, 1.500e+04, 2.880e+03,
#        1.800e+04, 2.800e+02])

# %%
df["Quenching"].unique()
# Out:
# <StringArray>
# [         nan,   '10�C/min',         'FC',         'AQ',  '10 �C/min',
#          'WQ',   '20 K/min', '10 K min?1',  '15 �C/min']
# Length: 9, dtype: str

# %%
df["Quenching"].value_counts(dropna=False) 

#will drop this column as not contain too much data in it and require conversion etc details
# Out:
# Quenching
# NaN           1092
# WQ             143
# AQ              45
# 20 K/min        27
# 10�C/min        22
# FC              16
# 10 K min?1       8
# 10 �C/min        5
# 15 �C/min        3
# Name: count, dtype: int64

# %%
df["HPR"].unique()
# Out:
# <StringArray>
# [nan, 'CW', 'CD', 'HW', 'HPT', 'Ti0', 'Ti0.2', 'Ti0.4', 'Ti0.5', 'Ti1.0',
#  'CR']
# Length: 11, dtype: str

# %%
df["Microstructure_"].unique()
# Out:
# <StringArray>
# [                   'BCC',               'BCC + Im',                    'FCC',
#             'BCC1 + BCC2',               'FCC + Im',              'FCC + BCC',
#             'BCC + delta',              'BCC + FCC',         'FCC + BCC + Im',
#      'BCC1 + BCC2 + BCC3',    'BCC1 + BCC2 + Laves',         'BCC + FCC + Im',
#        'BCC1 + BCC2 + Im',               'BCC?+ Im',              'BCC  + Im',
#             'BCC + Laves',              'BCC1+BCC2',              'BCC + BCC',
#               'BCC?+?FCC',      'BCC1 + BCC2 + FCC',               'Im + FCC',
#                      'Im',            'FCC + Laves',               'FCC+ BCC',
#         'FCC + FCC + BCC',                'BCC+ Im',               'BCC�+�Im',
#                'FCC + im',              'FCC1+FCC2',                'FCC +Im',
#            'FCC_PLUS_BCC',               'FCC+ FCC',        'FCC + FCC +  Im',
#         'BCC  + FCC + Im',      'FCC1 + FCC2 + BCC', 'BCC1 + BCC2 + FCC + Im',
# ...

# %%
df["Multiphase"].unique()
# Out:
# <StringArray>
# ['S', 'Im', 'D', 'M', nan]
# Length: 5, dtype: str

# %%
df["IM_Structure"].unique()
# Out:
# <StringArray>
# [                           nan,                        'Nb2Al',
#                           'L12',                        'Laves',
#                           'eta',                        'alpha',
#                      '(CoCr)Nb',                        'Delta',
#                         'MgZn2',                        'Sigma',
#                'AlFe0.23Ni0.77',                           'B2',
#                           'C14',                   'B2 + Sigma',
#                           'TiC',                        'M5Si3',
#                           'C15',                      'CrMn2O4',
#                        'Zr5Al3',                 'Zr5Al3 + C14',
#                          'anon',                 'Mg32(AlZn)49',
#                  'C14 + Zr2Al ', 'Mg2Sn/Li2MgSn + Zn + Al + Sn',
#       'Al + Mg2Sn/Li2MgSn + Sn',           'Al + Al2Cu + AlCu3',
#                         'M23C6',                           'Mu',
# ...

# %%
df["Microstructure"].unique()
# Out:
# <StringArray>
# ['BCC', 'BCC + Im', 'FCC', 'FCC + Im', 'FCC + BCC', 'FCC + BCC + Im', 'Im',
#  nan]
# Length: 8, dtype: str

# %%
df["Phases"].unique()
# Out:
# <StringArray>
# ['BCC_SS', 'Im', 'FCC_SS', 'FCC_PLUS_BCC', nan]
# Length: 5, dtype: str
